# %% [markdown]
# ## **Base de datos ChEMBL**

# %% [markdown]
# ## **Instalando librerías**

# %%
# !pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 5.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 6.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.1.0
#     Uninstalling attrs-23.1.0:
#       Successfully uninstalled attrs-23.1.0
# ...

# %% [markdown]
# ## **Importando librerías**

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Búsqueda del target**

# %% [markdown]
# ### **Serotonine**

# %%
target = new_client.target
target_query = target.search('6lu7')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#   cross_references                                         organism  \
# 0               []  Severe acute respiratory syndrome coronavirus 2
#
#                    pref_name  score  species_group_flag target_chembl_id  \
# 0  Replicase polyprotein 1ab    1.0               False    CHEMBL4523582
#
#                                    target_components     target_type   tax_id
# 0  [{'accession': 'P0DTD1', 'component_descriptio...  SINGLE PROTEIN  2697049

# %% [markdown]
# ### **Seleccionando y extrayendo la data de bioactividad**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL4523582'

# %% [markdown]
# Obteniendo la data de bioactividad y cargándola en DataFrame

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None  Dtt Insensitive
# 1                                                  None  Dtt Insensitive
# 2                                                  None  Dtt Insensitive
# 3                                                  None  Dtt Insensitive
# 4                                                  None  Dtt Insensitive
# ...                                                 ...              ...
# 1215  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1216  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1217  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1218  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1219  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id                                activity_properties  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1220 entries, 0 to 1219
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                942 non-null    object
#  1   activity_comment           192 non-null    object
#  2   activity_id                1220 non-null   int64
#  3   activity_properties        1220 non-null   object
#  4   assay_chembl_id            1220 non-null   object
#  5   assay_description          1220 non-null   object
#  6   assay_type                 1220 non-null   object
#  7   assay_variant_accession    0 non-null      object
#  8   assay_variant_mutation     0 non-null      object
#  9   bao_endpoint               1220 non-null   object
#  10  bao_format                 1220 non-null   object
#  11  bao_label                  1220 non-null   object
#  12  canonical_smiles           1213 non-null   object
# ...

# %%
df.shape
# Out:
# (1220, 46)

# %% [markdown]
# Guardando en **bioactivity_data.csv**.

# %%
df.to_csv('bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Datos perdidos**
# Si hay datos perdidos en las columnas **standard_value** y **canonical_smiles** estos son dropeados.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-11-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None  Dtt Insensitive
# 1                                                  None  Dtt Insensitive
# 2                                                  None  Dtt Insensitive
# 3                                                  None  Dtt Insensitive
# 4                                                  None  Dtt Insensitive
# ...                                                 ...              ...
# 1215  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1216  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1217  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 1218  {'action_type': 'INHIBITOR', 'description': 'N...             None
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1138 entries, 0 to 1219
# Data columns (total 46 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   action_type                942 non-null    object
#  1   activity_comment           110 non-null    object
#  2   activity_id                1138 non-null   int64
#  3   activity_properties        1138 non-null   object
#  4   assay_chembl_id            1138 non-null   object
#  5   assay_description          1138 non-null   object
#  6   assay_type                 1138 non-null   object
#  7   assay_variant_accession    0 non-null      object
#  8   assay_variant_mutation     0 non-null      object
#  9   bao_endpoint               1138 non-null   object
#  10  bao_format                 1138 non-null   object
#  11  bao_label                  1138 non-null   object
#  12  canonical_smiles           1138 non-null   object
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 919

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None  Dtt Insensitive     19964199                  []
# 1        None  Dtt Insensitive     19964200                  []
# 2        None  Dtt Insensitive     19964201                  []
# 3        None  Dtt Insensitive     19964202                  []
# 4        None  Dtt Insensitive     19964203                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 1   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 2   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 3   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
# 4   CHEMBL4495583  SARS-CoV-2 3CL-Pro protease inhibition IC50 de...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          F                    None                   None  BAO_0000190  ...
# ...

# %% [markdown]
# ## **Pre-procesamiento de los datos de bioactividad**

# %%
df2_nr["action_type"].value_counts()
# Out:
# {'action_type': 'INHIBITOR', 'description': 'Negatively effects (inhibits) the normal functioning of the protein e.g., prevention of enzymatic reaction or activation of downstream pathway', 'parent_type': 'NEGATIVE MODULATOR'}    740
# Name: action_type, dtype: int64

# %%
df4 = df2_nr.dropna(subset=["action_type"])
df4.head()
# Out:
#                                            action_type activity_comment  \
# 117  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 118  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 119  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 120  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 121  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#      activity_id                                activity_properties  \
# 117     23150136  [{'comments': None, 'relation': '=', 'result_f...
# 118     23150137  [{'comments': None, 'relation': '=', 'result_f...
# 119     23150138  [{'comments': None, 'relation': '=', 'result_f...
# 120     23150139  [{'comments': None, 'relation': '=', 'result_f...
# 121     23150140  [{'comments': None, 'relation': '=', 'result_f...
#
#     assay_chembl_id                                  assay_description  \
# ...

# %%
df4.shape
# Out:
# (740, 46)

# %% [markdown]
# ### **Combinar las 3 columnas (molecule_chembl_id,canonical_smiles,standard_value) y bioactivity_class en el DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df4[selection]
df3.head()
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 117      CHEMBL2316746  CC(C)C[C@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C)...
# 118       CHEMBL213543  CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...
# 119      CHEMBL4796938  O=C[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](CC1CCCCC1...
# 120      CHEMBL4764751  O=C[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](Cc1cccc(F...
# 121      CHEMBL4857345  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC(C...
#
#     standard_value
# 117           94.0
# 118          286.0
# 119           14.0
# 120           23.0
# 121           65.0

# %%
df3.shape
# Out:
# (740, 3)

# %% [markdown]
# Guardar dataframe como arvhico CSV

# %%
df3.to_csv('Bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Etiquetando compuestos como activos, inactivos o intermedios**
# La bioactividad se encuentra en unidades de IC50. Los compuestos teniendo valores menores que 1000 nM serán consideradas **active** mientas que mayores a 10 000 nM serán considerados como **inactive**. Valores entre 1,000 y 10,000 nM serán etiquetados como **intermediate**.

# %%
df4 = pd.read_csv('Bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0        CHEMBL2316746  CC(C)C[C@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C)...
# 1         CHEMBL213543  CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...
# 2        CHEMBL4796938  O=C[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](CC1CCCCC1...
# 3        CHEMBL4764751  O=C[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](Cc1cccc(F...
# 4        CHEMBL4857345  CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC(C...
# ..                 ...                                                ...
# 735      CHEMBL5220196  CC(C)C[C@H](NC(=O)OCCC12CC3CC(CC(C3)C1)C2)C(=O...
# 736      CHEMBL5220377  CC(C)C[C@H](NC(=O)OCC12CC3CC(CC(O)(C3)C1)C2)C(...
# 737      CHEMBL5219749  CC(C)C[C@H](NC(=O)OCC12CC3CC(CC(O)(C3)C1)C2)C(...
# 738      CHEMBL5218884  [2H]C([2H])(OC(=O)N[C@@H](CC(C)C)C(=O)N[C@H](C...
# 739      CHEMBL5220641  [2H]C([2H])(OC(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](...
#
#      standard_value         class
# 0              94.0        active
# ...

# %%
df6 = df5[df5["class"] == "active"]
df6.shape
# Out:
# (417, 4)

# %% [markdown]
# Saves dataframe to CSV file

# %%
df6.to_csv('Bioactivity_data_curated.csv', index=False)

# %%
df7 = df6['canonical_smiles']
df7.head()
# Out:
# 0    CC(C)C[C@H](NC(=O)[C@@H](NC(=O)OCc1ccccc1)C(C)...
# 1    CCOC(=O)/C=C/[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H]...
# 2    O=C[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](CC1CCCCC1...
# 3    O=C[C@H](C[C@@H]1CCNC1=O)NC(=O)[C@H](Cc1cccc(F...
# 4    CC(C)C[C@H](NC(=O)OCc1ccccc1)C(=O)N[C@@H](CC(C...
# Name: canonical_smiles, dtype: object

# %%
df7.to_csv("latent_data.csv", index=False, header=False)

# %%
! zip Bioactividad_df5.zip *.csv
# Out:
#   adding: Bioactivity_data_curated.csv (deflated 82%)
#   adding: Bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: bioactivity_data_raw.csv (deflated 91%)

# %% [markdown]
# ---
